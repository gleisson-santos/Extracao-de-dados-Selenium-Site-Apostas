# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import selenium.webdriver.remote.webdriver
import pandas as pd
import time

options = Options()
options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

link = ("https://pbdatatrader.com.br/jogosdodia")
driver.get(link)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 104.0.5112
# [WDM] - Get LATEST chromedriver version for 104.0.5112 google-chrome
# [WDM] - Driver [C:\Users\gleisson.santos\.wdm\drivers\chromedriver\win32\104.0.5112.79\chromedriver.exe] found in cache

# %%
while len(driver.find_elements(By.TAG_NAME, "iframe")) == 0:
    time.sleep(1)

#entrando no primeiro iframe
meu_iframe = driver.find_element(By.TAG_NAME, "iframe")
driver.switch_to.frame(meu_iframe)

#entrando no segundo iframe
meu_iframe = driver.find_element(By.TAG_NAME, "iframe")
driver.switch_to.frame(meu_iframe)
#driver, muda pro frame, iframe


texto = driver.find_element(
    By.XPATH,'//*[@id="pvExplorationHost"]/div/div/exploration/div/explore-canvas/div/div[2]/div/div[2]/div[2]/visual-container-repeat/visual-container[19]/transform/div/div[2]/div/visual-modern/div/div/div[2]/div[1]/div[2]/div[2]/div[1]/div')

print(texto.text)
# Out:
# Data

# %%
tabela = driver.find_element(By.CLASS_NAME, "innerContainer")

texto = tabela.text
print(texto)
# Out:
# Data
# Hora
# País
# Campeonato
# Mandante
# Visitante
# Pontos por Jogo Mandante
# Pontos por Jogo Visitante
# Média de Gols do Confronto
# % BTTS
# % Over 0.5 FT
# % Over 1.5 FT
# 13/08/2022
# 20:30
# Brazil
# Serie A
# Cuiabá
# Juventude
# 1,10
# 0,70
# 2,05
# 50
# 90
# 65
# 14/08/2022
# 12:30
# South Africa
# Premier Soccer League
# TS Galaxy
# SuperSport United
# 1,00
# 0,00
# 1,50
# 50
# 50
# 50
# 12/08/2022
# 08:00
# Vietnam
# V.League 2
# Bà Ria Vũng Tàu
# Quang Nam
# 1,60
# 0,80
# 1,60
# 30
# 80
# 40
# 12/08/2022
# 05:30
# Vietnam
# V.League 2
# Dak Lak
# Pho Hien
# 1,00
# 2,00
# 2,25
# 63
# 88
# 63
# 13/08/2022
# 06:00
# Vietnam
# V.League 2
# Bóng đá Huế
# Phu Dong
# 2,00
# 2,25
# 1,88
# 50
# 100
# 63
# 13/08/2022
# 06:30
# Vietnam
# V.League 2
# Công An Nhân Dân
# Sanna Khanh Hoa
# 2,50
# 2,50
# 1,88
# 38
# 88
# 63
# 12/08/2022
# 16:00
# Spain
# La Liga
# CA Osasuna
# Sevilla FC
# 0,00
# 0,00
# 0,00
# 0
# 0
# 0
# 13/08/2022
# 14:00
# France
# Ligue 2
# Bastia
# Grenoble Foot 38
# 0,00
# 1,00
# 1,00
# 0
# 50
# 50
# 13/08/2022
# 15:30
# Uruguay
# Primera División
# Rentistas
# Danubio
# 0,73
# 1,73
# 1,96
# 41
# 87
# 55
# 14/08/2022
# 11:00
# Brazil
# Serie B
# Novorizontino
# Criciúma
# 1,50
# 1,00
# 2,13
# 57
# 87
# 70
# 14/08/2022
# 07:00
# Japan
# J2 League
# Tokushima Vortis
# Oita Trinita
# 1,29
# 1,54
# 1,94
# 49
# 82
# 56
# 14/08/2022
# 17:00
# Spain
# Segunda División
# Burgos CF
# Málaga CF
# 0,00
# 0,00
# 0,00
# 0
# 0
# 0
# 14/08/2022
# 12:30
# Spain
# Segunda División
# Racing Santander
# Villarreal II
# 0,00
# 0,00
# 0,00
# 0
# 0
# 0
# 12/08/2022
# 12:00
# Iran
# Persian Gulf Pro League
# Esteghlal
# Sepahan
# 0,00
# 0,00
# 0,00
# 0
# 0
# 0
# 13/08/2022
# 11:00
# Brazil
# Serie B
# Operário PR
# Sampaio Corrêa
# 1,55
# 0,25
# 2,01
# 35
# 83
# 57
# 13/08/2022
# 14:00
# France
# Ligue 2
# Annecy
# Laval
# 0,00
# 3,00
# 2,50
# 50
# 100
# 100
# 14/08/2022
# 17:00
# Colombia
# Categoria Primera B
# Atlético
# Orsomarso
# 1,38
# 1,11
# 2,35
# 41
# 89
# 53
# 13/08/2022
# 10:00
# South Africa
# Premier Soccer League
# Mamelodi Sundowns
# Kaizer Chiefs
# 0,00
# 0,00
# 1,00
# 0
# 100
# 0
# 12/08/2022
# 15:30
# Argentina
# Primera C
# Central Córdoba
# Argentino Merlo
# 1,54
# 1,33
# 2,13
# 52
# 85
# 52
# 12/08/2022
# 14:30
# France
# National
# Versailles
# Martigues
# 0,00
# 0,00
# 0,00
# 0
# 0
# 0
# 12/08/2022
# 19:00
# Uruguay
# Primera División
# Plaza Colonia
# Cerro Largo
# 1,09
# 0,69
# 1,74
# 34
# 91
# 66
# 13/08/2022
# 11:00
# England
# Championship
# Millwall
# Coventry City
# 3,00
# 1,00
# 2,00
# 50
# 100
# 100
# 13/08/2022
# 06:00
# Japan
# J2 League
# Grulla Morioka
# Blaublitz Akita
# 0,80
# 1,06
# 2,37
# 42
# 87
# 58
# 13/08/2022
# 15:45
# Romania
# Liga I
# Petrolul 52
# Rapid Bucureşti
# 0,50
# 1,50
# 1,25
# 25
# 100
# 25
# 13/08/2022
# 13:00
# Romania
# Liga I
# UTA Arad
# Universitatea Cluj
# 3,00
# 0,50
# 2,50
# 50
# 100
# 100

# %%
lista_texto = texto.split('\n')
colunas = lista_texto[:12]
valores = lista_texto[11:]

# %%
print(colunas)
print(valores)
# Out:
# ['Data', 'Hora', 'País', 'Campeonato', 'Mandante', 'Visitante', 'Pontos por Jogo Mandante', 'Pontos por Jogo Visitante', 'Média de Gols do Confronto', '% BTTS', '% Over 0.5 FT', '% Over 1.5 FT']
# ['% Over 1.5 FT', '13/08/2022', '20:30', 'Brazil', 'Serie A', 'Cuiabá', 'Juventude', '1,10', '0,70', '2,05', '50', '90', '65', '14/08/2022', '12:30', 'South Africa', 'Premier Soccer League', 'TS Galaxy', 'SuperSport United', '1,00', '0,00', '1,50', '50', '50', '50', '12/08/2022', '08:00', 'Vietnam', 'V.League 2', 'Bà Ria Vũng Tàu', 'Quang Nam', '1,60', '0,80', '1,60', '30', '80', '40', '12/08/2022', '05:30', 'Vietnam', 'V.League 2', 'Dak Lak', 'Pho Hien', '1,00', '2,00', '2,25', '63', '88', '63', '13/08/2022', '06:00', 'Vietnam', 'V.League 2', 'Bóng đá Huế', 'Phu Dong', '2,00', '2,25', '1,88', '50', '100', '63', '13/08/2022', '06:30', 'Vietnam', 'V.League 2', 'Công An Nhân Dân', 'Sanna Khanh Hoa', '2,50', '2,50', '1,88', '38', '88', '63', '12/08/2022', '16:00', 'Spain', 'La Liga', 'CA Osasuna', 'Sevilla FC', '0,00', '0,00', '0,00', '0', '0', '0', '13/08/2022', '14:00', 'France', 'Ligue 2', 'Bastia', 'Grenoble Foot 38', '0,00', '1,00', '1,00', '0', '50', '50', '13/08/2022', '15:30', 'Uruguay', 'Primera División', 'Rentistas', 'Danubio', '0,73', '1,73', '1,96', '41', '87', '55', '14/08/2022', '11:00', 'Brazil', 'Serie B', 'Novorizontino', 'Criciúma', '1,50', '1,00', '2,13', '57', '87', '70', '14/08/2022', '07:00', 'Japan', 'J2 League', 'Tokushima Vortis', 'Oita Trinita', '1,29', '1,54', '1,94', '49', '82', '56', '14/08/2022', '17:00', 'Spain', 'Segunda División', 'Burgos CF', 'Málaga CF', '0,00', '0,00', '0,00', '0', '0', '0', '14/08/2022', '12:30', 'Spain', 'Segunda División', 'Racing Santander', 'Villarreal II', '0,00', '0,00', '0,00', '0', '0', '0', '12/08/2022', '12:00', 'Iran', 'Persian Gulf Pro League', 'Esteghlal', 'Sepahan', '0,00', '0,00', '0,00', '0', '0', '0', '13/08/2022', '11:00', 'Brazil', 'Serie B', 'Operário PR', 'Sampaio Corrêa', '1,55', '0,25', '2,01', '35', '83', '57', '13/08/2022', '14:00', 'France', 'Ligue 2', 'Annecy', 'Laval', '0,00', '3,00', '2,50', '50', '100', '100', '14/08/2022', '17:00', 'Colombia', 'Categoria Primera B', 'Atlético', 'Orsomarso', '1,38', '1,11', '2,35', '41', '89', '53', '13/08/2022', '10:00', 'South Africa', 'Premier Soccer League', 'Mamelodi Sundowns', 'Kaizer Chiefs', '0,00', '0,00', '1,00', '0', '100', '0', '12/08/2022', '15:30', 'Argentina', 'Primera C', 'Central Córdoba', 'Argentino Merlo', '1,54', '1,33', '2,13', '52', '85', '52', '12/08/2022', '14:30', 'France', 'National', 'Versailles', 'Martigues', '0,00', '0,00', '0,00', '0', '0', '0', '12/08/2022', '19:00', 'Uruguay', 'Primera División', 'Plaza Colonia', 'Cerro Largo', '1,09', '0,69', '1,74', '34', '91', '66', '13/08/2022', '11:00', 'England', 'Championship', 'Millwall', 'Coventry City', '3,00', '1,00', '2,00', '50', '100', '100', '13/08/2022', '06:00', 'Japan', 'J2 League', 'Grulla Morioka', 'Blaublitz Akita', '0,80', '1,06', '2,37', '42', '87', '58', '13/08/2022', '15:45', 'Romania', 'Liga I', 'Petrolul 52', 'Rapid Bucureşti', '0,50', '1,50', '1,25', '25', '100', '25', '13/08/2022', '13:00', 'Romania', 'Liga I', 'UTA Arad', 'Universitatea Cluj', '3,00', '0,50', '2,50', '50', '100', '100']
